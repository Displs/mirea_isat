# %% [markdown]
# ## Доп. файл, чтобы не поломать проект

# %%
from PyARMViz import datasets
from PyARMViz import PyARMViz

rules = datasets.load_shopping_rules()
PyARMViz.adjacency_graph_plotly(rules)

# %%
PyARMViz.adjacency_parallel_category_plot(rules)

# %%
PyARMViz.adjacency_parallel_coordinate_plot(rules)

# %%
PyARMViz.adjacency_scatter_plot(rules=rules)

# %%
PyARMViz.adjacency_graph_gephi(rules=rules, output_path='./test')

# %%
import networkx as nx

# %%
graph_a = PyARMViz._adjacency_graph_generator(rules=rules)

# %%
nx.draw_networkx(graph_a, with_labels=True)

# %%
import pandas as pd

# %%
data_test = pd.read_csv('./Prac_1_2.csv', sep=';')

# %%
data_test
# Out:
#     Транзакция     Товар
# 0            1   Конфеты
# 1            1   Чизкейк
# 2            1   Шоколад
# 3            1     Эклер
# 4            1     Пирог
# ..         ...       ...
# 77          19   Печенье
# 78          20     Эклер
# 79          20   Пряники
# 80          20  Круассан
# 81          20   Чизкейк
#
# [82 rows x 2 columns]

# %%
transactions = data_test.groupby('Транзакция')['Товар'].apply(list).to_list()

# %%
from fpgrowth_py import fpgrowth

# %%
from efficient_apriori import apriori


itemsets, rules = apriori(transactions, min_support=0.6, min_confidence=0.6)
print(rules)  # [{eggs} -> {bacon}, {soup} -> {bacon}]
# Out:
# [{Эклер} -> {Чизкейк}, {Чизкейк} -> {Эклер}, {Эклер} -> {Шоколад}, {Шоколад} -> {Эклер}]

# %%
PyARMViz.adjacency_graph_plotly(rules=rules)

# %%
PyARMViz.adjacency_graph_gephi(rules=rules, output_path='rule.gefx')

# %%
PyARMViz.metadata_scatter_plot(rules=rules)
